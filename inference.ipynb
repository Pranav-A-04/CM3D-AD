# %% [markdown]
# To connect to a GPU runtime in Google Colab (Only required if trying to execute with GPU):
#
# 1. Go to the "Runtime" menu at the top of the page.
# 2. Select "Change runtime type".
# 3. In the "Hardware accelerator" dropdown menu, select "GPU".
# 4. Click "Save".
#
# Your notebook will now be connected to a GPU runtime.

# %% [markdown]
# Upload zip file to Google Drive before running the following cells

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import zipfile

zip_file_path = '/content/drive/My Drive/your_folder_name/your_zip_file.zip' # Replace with your actual path

extract_dir = '/content/' 

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"Successfully unzipped {zip_file_path} to {extract_dir}")

# %% [markdown]
# Run the below cell to download dependencies

# %%
# !make -sC Fast-CMAD download-dependencies

# %% [markdown]
# Run the below cell to see inference time for FAST-CMAD for all objects.
#
# Refer README and Makefile to run inference for a particular object

# %%
# !make -sC Fast-CMAD inference-consistency

# %% [markdown]
# Run the below cell to see inference time for Diffusion Model (R3D-AD) for all objects.
#
# Refer README and Makefile to run inference for a particular object

# %%
# !make -sC Fast-CMAD inference-diffusion
